# %% [markdown]
# # Homework 07: Objektorientierte Programmierung, konzeptionelle Modellierung mit UML und Vibe Coding
#
# In dieser Hausaufgabe vertiefen Sie die objektorientierte Programmierung in Python, die
# konzeptionelle Modellierung mit UML und den neuartigen Vibe-Coding-Ansatz mittels KI-Werkzeugen.
#
# ---
#
# ## Lernziele
#
# - Eine bestehende **Vererbungshierarchie** um eine neue Klasse erweitern und die Einordnung begründen.
# - Ein **UML-Klassendiagramm** notationsgerecht zeichnen: abstrakte Klassen, Sichtbarkeit, Typen, Generalisierung.
# - Eine Klassenstruktur per **Vibe Coding** aus einem Modell heraus implementieren lassen.
#
# ## Bearbeitungshinweise
#
# - Ersetzen Sie jedes `# TODO` durch Ihren Code und jedes _TODO_ durch Ihre Antwort.
# - Der Code, den Sie erzeugen lassen, erhält **Docstrings** (PEP 257) und **Type Hints** für alle Parameter und Rückgabewerte (PEP 484).
# - Führen Sie am Ende **Kernel → Restart & Run All** aus, damit alle Zellen von oben nach unten fehlerfrei laufen.

# %% [markdown]
# ---
#
# ## Ausgangspunkt: Die Klassenhierarchie der geometrischen Formen
#
# Alle geschlossenen Formen der Ebene haben eine Fläche und einen Umfang. Das ist die
# gemeinsame Schnittstelle der Oberklasse `Form`. Das folgende Klassendiagramm zeigt den
# aktuellen Stand des Modells:
#
# ![class diagram](class_diagramm.png)
#
# So lesen Sie das Diagramm:
#
# | Notation | Bedeutung |
# |---|---|
# | **Kursiver** Klassenname | Die Klasse ist **abstrakt** und kann nicht instanziiert werden. Sie legt die Schnittstelle fest, implementiert sie aber nicht vollständig. |
# | Durchgezogene Linie mit **hohlem Dreieck** | **Generalisierung** (Vererbung). Die Spitze zeigt auf die Oberklasse. |
# | Oberes Fach | Klassenname |
# | Mittleres Fach | Attribute in der Form `name: Typ` |
# | Unteres Fach | Operationen |
#
# Zwei Details lohnen einen zweiten Blick:
#
# - `Polygon` implementiert `umfang()` bereits vollständig, obwohl die Klasse `punkte()` selbst gar nicht implementiert. Das funktioniert, weil `self.punkte()` immer ab der **tatsächlichen** Klasse des Objekts gesucht wird.
# - `Rechteck` erbt einen funktionierenden `umfang()` und **überschreibt ihn trotzdem**, weil sich der Umfang aus Breite und Höhe direkt und exakt berechnen lässt. `Dreieck` überschreibt `umfang()` dagegen nicht.

# %% [markdown]
# ---
#
# # Aufgabe 1: Das Klassendiagramm um `Quadrat` erweitern
#
# Das Modell soll um die Klasse `Quadrat` erweitert werden.
#
# ### 1a) Wo gehört `Quadrat` in die Hierarchie?
#
# Ein Quadrat ist ein Rechteck mit vier gleich langen Seiten. Ordnen Sie `Quadrat` deshalb als
# **Unterklasse von `Rechteck`** ein.
#
# Beantworten Sie in der nächsten Zelle in je ein bis zwei Sätzen:
#
# 1. Warum ist `Rechteck` die passende Oberklasse und nicht `Polygon` oder `Form`? Argumentieren Sie mit der **„ist ein"-Beziehung**.
# 2. Welche der Operationen `flaeche()`, `umfang()` und `punkte()` muss `Quadrat` selbst implementieren, welche erbt es unverändert? Begründen Sie.
# 3. `Quadrat` wird durch **eine** Ecke und **eine** Seitenlänge festgelegt, `Rechteck` durch zwei Ecken. Wie lässt sich das auflösen, ohne die geerbten Attribute `p1` und `p2` aufzugeben?

# %% [markdown]
# > **Ihre Antwort zu 1a):**
# >
# > 1. _TODO_
# > 2. _TODO_
# > 3. _TODO_

# %% [markdown]
# ### 1b) Das Diagramm mit draw.io zeichnen
#
# Zeichnen Sie das **vollständige** Klassendiagramm – also alle bestehenden Klassen **und** `Quadrat` –
# mit draw.io neu.
#
# **draw.io einrichten**
#
# 1. Öffnen Sie [app.diagrams.net](https://app.diagrams.net) im Browser oder die Desktop-App und legen Sie ein leeres Diagramm an.
# 2. Klicken Sie links unten auf **Mehr Formen…**, aktivieren Sie in der Kategorie **Software** den Eintrag **UML** und bestätigen Sie mit **Übernehmen**.
# 3. Ziehen Sie die Form **Class 2** (Kasten mit drei Fächern) auf die Zeichenfläche. Ein Doppelklick auf ein Fach bearbeitet den Text, `Umschalt`+`Enter` fügt innerhalb eines Fachs eine neue Zeile ein.
#
# **Anforderungen an Ihr Diagramm**
#
# - Alle sechs bestehenden Klassen und zusätzlich `Quadrat`.
# - Abstrakte Klassen (`Form`, `Polygon`) **kursiv** setzen.
# - Attribute mit **Sichtbarkeit und Typ**, zum Beispiel `- radius: int | float`. Verwenden Sie `-` für private und `+` für öffentliche Elemente.
# - Operationen mit **Sichtbarkeit und Rückgabetyp**, zum Beispiel `+ flaeche(): int | float`.
# - Für `Quadrat`: das Attribut `- seite: int | float` mit der Restriktion `{seite > 0}` und ein **leeres** Operationsfach – genau das ist die Aussage, dass nichts überschrieben wird.
# - **Generalisierung** als durchgezogene Linie mit hohlem Dreieck: Wählen Sie die Kante aus und stellen Sie im Format-Panel unter **Linie → Linienende** die Spitze **Block** mit **Füllung: transparent** ein.
#
# **Speichern und exportieren**
#
# - **Datei → Speichern unter…** → `klassendiagramm.drawio` (die bearbeitbare Quelldatei).
# - **Datei → Exportieren als → PNG…**, Option **Diagramm einbetten** aktivieren → `klassendiagramm.png`.
#
# Beide Dateien legen Sie in Aufgabe 3 im Git-Repository ab.

# %% [markdown]
# ---
#
# # Aufgabe 2: Die Implementierung per Vibe Coding erzeugen (ca. 20 Minuten)
#
# Beim **Vibe Coding** beschreiben Sie das gewünschte Ergebnis in natürlicher Sprache und lassen den
# Code von einem KI-Werkzeug erzeugen, statt ihn Zeile für Zeile selbst zu schreiben. Ihre Arbeit
# verlagert sich damit von der Syntax auf die **konzeptionelle Anleitung**: Sie liefern das Modell,
# setzen den Rahmen und prüfen an definierten Checkpoints, ob das Ergebnis stimmt.
#
# Genau dafür haben Sie in Aufgabe 1 vorgearbeitet. Das Klassendiagramm ist Ihre Spezifikation.
#
# ### 2a) Den Prompt formulieren
#
# Schreiben Sie einen Prompt für Ihr KI-Werkzeug (GitHub Copilot Chat in PyCharm, oder ein Chat-Modell
# Ihrer Wahl). Ein brauchbarer Prompt für diese Aufgabe enthält vier Bestandteile:
#
# | Bestandteil | Was hineingehört |
# |---|---|
# | **Kontext** | Sprache, Version, Zielsetzung: eine Datei `formen.py`, reine Standardbibliothek, keine Fremdpakete. |
# | **Modell** | Die Hierarchie in Textform oder als eingefügtes Diagrammbild: welche Klasse erbt von welcher, welche Attribute und Operationen es gibt. |
# | **Rahmen** | Verbindliche Vorgaben: `abc.ABC` und `@abstractmethod` für die abstrakten Klassen, `Punkt` als `@dataclass(frozen=True)`, Type Hints, Docstrings, Plausibilitätsprüfungen im Konstruktor mit `ValueError`. |
# | **Checkpoint** | Was am Ende gelten muss: `Form()` und `Polygon()` lösen einen `TypeError` aus, `Quadrat` überschreibt keine der drei Operationen, `Quadrat(Punkt(0, 0), 4)` hat Fläche 16 und Umfang 16. |
#
# Notieren Sie Ihren Prompt in der nächsten Zelle. Der Prompt ist Teil der Abgabe.

# %% [markdown]
# > **Ihr Prompt:**
# >
# > _TODO_
# Erstelle eine Datei formen.py in Python , ohne dabei jegliche Fremdpakete einzubinden, nur Standardbibliotheken sind erlaubt. Beim Inhalt muss man sich an die Struktur in in der eingefügten Bilddatei class_diagramm.png halten. Die Datei wird zusätzlich zur Verfügung gestellt. Beachte weiterhin alle Huinweise in den Markdowns von Aufgabe 1 und 2 oben, besonders wenn es um Objektorientierung geht.

# %% [markdown]
# ### 2b) Den Code erzeugen lassen und einfügen
#
# Lassen Sie sich den Code erzeugen und fügen Sie ihn **vollständig** in die nächste Zelle ein.

# %%
# TODO: den vollstaendig generierten Inhalt von formen.py hier einfuegen

# %% [markdown]
# ---
#
# # Aufgabe 3: Das Ergebnis im Git-Repository ablegen
#
# Legen Sie ihre erstellten Dateien und den implementierten Code in dem neu erstellten Git-Repository ab. Committen sie alle erstellten Dateien und pushen sie den neuen Stand auf GitHub.

# %% [markdown]
# #Inhalt der Datei formen.py
# # ChatGPT:
# # https://chatgpt.com/s/t_6aa0190efec88191b11842a2f0fea98b****
#
#
# """Geometrische Formen nach der vorgegebenen UML-Klassenhierarchie.
#
# Die Implementierung verwendet ausschließlich Module aus der Python-Standardbibliothek.
# """
#
# from abc import ABC, abstractmethod
# from dataclasses import dataclass
# from math import pi, sqrt
# from typing import Iterable, Iterator
#
#
# @dataclass(frozen=True)
# class Punkt:
#     """Unveränderlicher Punkt in der Ebene."""
#
#     x: int | float
#     y: int | float
#
#
# class Form(ABC):
#     """Abstrakte Oberklasse für geschlossene geometrische Formen."""
#
#     @abstractmethod
#     def flaeche(self) -> int | float:
#         """Gibt die Fläche der Form zurück."""
#         raise NotImplementedError
#
#     @abstractmethod
#     def umfang(self) -> int | float:
#         """Gibt den Umfang der Form zurück."""
#         raise NotImplementedError
#
#
# class Kreis(Form):
#     """Kreis mit einem Mittelpunkt und einem positiven Radius."""
#
#     def __init__(self, center: Punkt, radius: int | float) -> None:
#         """Erzeugt einen Kreis."""
#         if not isinstance(center, Punkt):
#             raise ValueError("center muss ein Punkt sein.")
#         if not isinstance(radius, (int, float)) or isinstance(radius, bool):
#             raise ValueError("radius muss eine Zahl sein.")
#         if radius <= 0:
#             raise ValueError("radius muss größer als 0 sein.")
#
#         self.center = center
#         self.radius = radius
#
#     def flaeche(self) -> float:
#         """Gibt die Kreisfläche zurück."""
#         return pi * self.radius**2
#
#     def umfang(self) -> float:
#         """Gibt den Kreisumfang zurück."""
#         return 2 * pi * self.radius
#
#
# class Polygon(Form, ABC):
#     """Abstrakte Oberklasse für Polygone."""
#
#     @abstractmethod
#     def punkte(self) -> Iterable[Punkt]:
#         """Liefert die Eckpunkte des Polygons in ihrer Reihenfolge."""
#         raise NotImplementedError
#
#     def umfang(self) -> float:
#         """Berechnet den Umfang aus den aufeinanderfolgenden Eckpunkten."""
#         punkte = list(self.punkte())
#
#         if len(punkte) < 3:
#             raise ValueError("Ein Polygon benötigt mindestens drei Punkte.")
#
#         umfang = 0.0
#         for p1, p2 in zip(punkte, punkte[1:] + punkte[:1]):
#             umfang += sqrt((p2.x - p1.x) ** 2 + (p2.y - p1.y) ** 2)
#
#         return umfang
#
#     def print(self) -> None:
#         """Gibt die wichtigsten Daten des Polygons aus."""
#         print(f"Fläche: {self.flaeche()}")
#         print(f"Umfang: {self.umfang()}")
#         print(f"Punkte: {list(self.punkte())}")
#
#
# class Rechteck(Polygon):
#     """Rechteck, das durch zwei gegenüberliegende Ecken festgelegt wird."""
#
#     def __init__(self, p1: Punkt, p2: Punkt) -> None:
#         """Erzeugt ein achsenparalleles Rechteck aus zwei gegenüberliegenden Ecken."""
#         if not isinstance(p1, Punkt) or not isinstance(p2, Punkt):
#             raise ValueError("p1 und p2 müssen Punkte sein.")
#         if p1.x == p2.x or p1.y == p2.y:
#             raise ValueError("p1 und p2 müssen unterschiedliche x- und y-Koordinaten haben.")
#
#         self.p1 = p1
#         self.p2 = p2
#
#     def flaeche(self) -> float:
#         """Gibt die Rechteckfläche zurück."""
#         breite = abs(self.p2.x - self.p1.x)
#         hoehe = abs(self.p2.y - self.p1.y)
#         return breite * hoehe
#
#     def umfang(self) -> float:
#         """Gibt den Rechteckumfang zurück."""
#         breite = abs(self.p2.x - self.p1.x)
#         hoehe = abs(self.p2.y - self.p1.y)
#         return 2 * (breite + hoehe)
#
#     def punkte(self) -> Iterator[Punkt]:
#         """Liefert die vier Eckpunkte des achsenparallelen Rechtecks."""
#         x_min = min(self.p1.x, self.p2.x)
#         x_max = max(self.p1.x, self.p2.x)
#         y_min = min(self.p1.y, self.p2.y)
#         y_max = max(self.p1.y, self.p2.y)
#
#         yield Punkt(x_min, y_min)
#         yield Punkt(x_max, y_min)
#         yield Punkt(x_max, y_max)
#         yield Punkt(x_min, y_max)
#
#
# class Dreieck(Polygon):
#     """Dreieck, das durch drei Eckpunkte festgelegt wird."""
#
#     def __init__(self, p1: Punkt, p2: Punkt, p3: Punkt) -> None:
#         """Erzeugt ein Dreieck aus drei nicht kollinearen Punkten."""
#         if not all(isinstance(p, Punkt) for p in (p1, p2, p3)):
#             raise ValueError("p1, p2 und p3 müssen Punkte sein.")
#
#         doppelte_punkte = len({p1, p2, p3}) != 3
#         if doppelte_punkte:
#             raise ValueError("Ein Dreieck benötigt drei verschiedene Punkte.")
#
#         doppelter_flaecheninhalt = (
#             (p2.x - p1.x) * (p3.y - p1.y)
#             - (p2.y - p1.y) * (p3.x - p1.x)
#         )
#         if doppelter_flaecheninhalt == 0:
#             raise ValueError("Die drei Punkte dürfen nicht auf einer Geraden liegen.")
#
#         self.p1 = p1
#         self.p2 = p2
#         self.p3 = p3
#
#     def flaeche(self) -> float:
#         """Gibt die Dreiecksfläche zurück."""
#         return abs(
#             (self.p1.x * (self.p2.y - self.p3.y)
#              + self.p2.x * (self.p3.y - self.p1.y)
#              + self.p3.x * (self.p1.y - self.p2.y))
#             / 2
#         )
#
#     def punkte(self) -> tuple[Punkt, Punkt, Punkt]:
#         """Liefert die drei Eckpunkte des Dreiecks."""
#         return self.p1, self.p2, self.p3
#
#
# class Quadrat(Rechteck):
#     """Rechteck mit vier gleich langen Seiten.
#
#     Das Quadrat überschreibt keine der drei Operationen flaeche(), umfang()
#     und punkte(), sondern verwendet die Implementierungen von Rechteck bzw.
#     Polygon.
#     """
#
#     def __init__(self, p1: Punkt, seite: int | float) -> None:
#         """Erzeugt ein achsenparalleles Quadrat aus einer Ecke und der Seitenlänge."""
#         if not isinstance(p1, Punkt):
#             raise ValueError("p1 muss ein Punkt sein.")
#         if not isinstance(seite, (int, float)) or isinstance(seite, bool):
#             raise ValueError("seite muss eine Zahl sein.")
#         if seite <= 0:
#             raise ValueError("seite muss größer als 0 sein.")
#
#         self.seite = seite
#
#         # Das zweite Rechteckattribut wird aus Ecke und Seitenlänge abgeleitet.
#         p2 = Punkt(p1.x + seite, p1.y + seite)
#         super().__init__(p1, p2)
#
#
# if __name__ == "__main__":
#     quadrat = Quadrat(Punkt(0, 0), 4)
#     print(f"Quadratfläche: {quadrat.flaeche()}")
#     print(f"Quadratumfang: {quadrat.umfang()}")
